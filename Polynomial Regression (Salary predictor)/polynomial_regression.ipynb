# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree=4)
x_poly = poly_reg.fit_transform(x)

lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(x,y,color="red")
plt.plot(x,lin_reg.predict(x),color='blue')
plt.title("Graph for LR")
plt.xlabel("position level")
plt.ylabel("salary")
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(x,y,color="red")
plt.plot(x,lin_reg_2.predict(x_poly),color='blue')
plt.title("Graph for Poly_LR")
plt.xlabel("position level")
plt.ylabel("salary")
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
predicted_salary_lin =  lin_reg.predict([[6.5]])
print(predicted_salary_lin)
# Out:
# [330378.78787879]

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
predicted_salary_poly =  lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
print(predicted_salary_poly)
# Out:
# [158862.45265155]
